# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

header = {'User-Agent':"Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36"}

# %%
URL = 'https://en.wikipedia.org/wiki/Languages_with_official_status_in_India#List_of_official_languages_by_states_and_territories'

# %%
r = requests.get(URL, headers = header)
soup = BeautifulSoup(r.content,'html5lib')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en"><head>
# <meta charset="utf-8"/>
# <title>Languages with official status in India - Wikipedia</title>
# ...

# %%
tables = soup.find_all('table')

# %%
by_states = tables[1]
by_territories = tables[2]
scripts = tables[3]

# %%
tds = [row.text for row in by_states.findAll('td')]

# %%
states = [tds[i] for i in range(0,len(tds)) if i%4 == 1]
states
len(states)
# Out:
# 28

# %%
Off_lang = [tds[i] for i in range(0,len(tds)) if i%4==2]
Off_lang
len(Off_lang)
# Out:
# 28

# %%
Other_offs = [tds[i] for i in range(0,len(tds)) if i%4==3]
Other_offs
len(Other_offs)
# Out:
# 28

# %%
d = {'state':states, 'Official Language(s)':Off_lang, 'Other Official Language(s)':Other_offs}
states_df = pd.DataFrame(data=d)

# %%
tds = [row.text for row in by_territories.findAll('td')]

# %%
territories = [tds[i] for i in range(0,len(tds)) if i%4 == 1]
territories
len(territories)
# Out:
# 8

# %%
Off_lang = [tds[i] for i in range(0,len(tds)) if i%4==2]
Off_lang
len(Off_lang)
# Out:
# 8

# %%
Other_offs = [tds[i] for i in range(0,len(tds)) if i%4==3]
Other_offs
len(Other_offs)
# Out:
# 8

# %%
d= {'territory':territories, 'Official Language(s)':Off_lang, 'Other Official Language(s)':Other_offs}
territory_df = pd.DataFrame(data=d)

# %%
tds = [row.text for row in scripts.findAll('td')]

# %%
scripts = [tds[i] for i in range(0,len(tds)) if i%2==0 or i%2==2]

# %%
languages = [tds[i] for i in range(0,len(tds)) if i%2==1]

# %%
d ={'script':scripts, 'Scheduled languages':languages} 
scripts_df = pd.DataFrame(data=d)

# %%
states_df
# Out:
#                 state                        Official Language(s)  \
# 0      Andhra Pradesh                        Telugu,[63] Urdu[23]
# 1   Arunachal Pradesh                                 English[64]
# 2               Assam                                Assamese[65]
# 3               Bihar                                   Hindi[67]
# 4        Chhattisgarh                Hindi,[68] Chhattisgarhi[69]
# 5                 Goa                        Konkani, English[70]
# 6             Gujarat                                Gujarati[73]
# 7             Haryana                                   Hindi[74]
# 8    Himachal Pradesh                                   Hindi[76]
# 9           Jharkhand                                   Hindi[64]
# 10          Karnataka                                     Kannada
# 11             Kerala                                   Malayalam
# 12     Madhya Pradesh                                   Hindi[79]
# ...

# %%
territory_df
# Out:
#                                   territory  \
# 0               Andaman and Nicobar Islands
# 1                                Chandigarh
# 2  Dadra and Nagar Haveli and Daman and Diu
# 3                                     Delhi
# 4                               Lakshadweep
# 5                         Jammu and Kashmir
# 6                                    Ladakh
# 7                                Puducherry
#
#                          Official Language(s)  \
# 0                              Hindi, English
# 1                               English[97]\n
# 2   Gujarati, English, Marathi, Hindi[98][99]
# 3                          Hindi, English[64]
# 4                              Malayalam[101]
# 5  Kashmiri, Dogri, Hindi, Urdu, English[102]
# 6                              Hindi, English
# 7                 Tamil, French,[103] English
#
#                           Other Official Language(s)
# 0           Bengali, Tamil, Telugu, Andamanese[96]\n
# ...

# %%
scripts_df
# Out:
#                  script                                Scheduled languages
# 0         Devanagari[d]  Bodo, Dogri, Hindi, Konkani[e], Maithili, Mara...
# 1        Eastern Nagari                                Assamese, Bengali\n
# 2              Gujarati                                         Gujarati\n
# 3              Gurmukhi                                          Punjabi\n
# 4            Kannada[g]                                          Kannada\n
# 5             Malayalam                                        Malayalam\n
# 6             Meitei[h]                                         Manipuri\n
# 7                  Odia                                            Oriya\n
# 8              Ol Chiki                                          Santali\n
# 9   Perso-Arabic script                        Kashmiri[i], Sindhi, Urdu\n
# 10                Tamil                                            Tamil\n
# ...

# %%
new_df = states_df.append(territory_df)

# %%
new_df.to_csv('places.csv',index=False)
scripts_df.to_csv('scripts.csv',index=False)
